# %% [markdown]
# <a href="https://colab.research.google.com/github/Lindbeck99/Cursos_Python/blob/main/Pandas/Aula2_Dataframe_Basics/Aula_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas
arquivo = pandas.read_csv('/content/wheater_data.csv')
arquivo
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow
# 3  1/4/2017           24          7   Snow
# 4  1/5/2017           32          4   Rain
# 5  1/6/2017           31          2  Sunny

# %%
rows, columns = arquivo.shape
rows
# Out:
# 6

# %%
arquivo.head(2)
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny

# %%
arquivo.tail(2)
# Out:
#         day  temperature  windspeed  event
# 4  1/5/2017           32          4   Rain
# 5  1/6/2017           31          2  Sunny

# %%
arquivo.columns
# Out:
# Index(['day', 'temperature', 'windspeed', 'event'], dtype='object')

# %%
print(arquivo.temperature.max())
print(arquivo.temperature.mean())
print(arquivo.temperature.min())
# Out:
# 35
# 30.333333333333332
# 24

# %%
arquivo.describe()
# Out:
#        temperature  windspeed
# count     6.000000   6.000000
# mean     30.333333   4.666667
# std       3.829708   2.338090
# min      24.000000   2.000000
# 25%      28.750000   2.500000
# 50%      31.500000   5.000000
# 75%      32.000000   6.750000
# max      35.000000   7.000000

# %%
arquivo[['day', 'temperature']][arquivo.temperature<arquivo.temperature.mean()]
# Out:
#         day  temperature
# 2  1/3/2017           28
# 3  1/4/2017           24

# %%
arquivo.set_index('day', inplace=True)

# %%
arquivo.loc['1/4/2017']
# Out:
# temperature      24
# windspeed         7
# event          Snow
# Name: 1/4/2017, dtype: object

# %%
arquivo.reset_index(inplace=True)
arquivo
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow
# 3  1/4/2017           24          7   Snow
# 4  1/5/2017           32          4   Rain
# 5  1/6/2017           31          2  Sunny
